# %%
# !pip install openpyxl
# !pip install xlrd
# Out:
# Requirement already satisfied: openpyxl in /opt/anaconda3/lib/python3.12/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /opt/anaconda3/lib/python3.12/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: xlrd in /opt/anaconda3/lib/python3.12/site-packages (2.0.1)

# %%
#importing all the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid') #this is for background
from scipy import stats

#inorder to avoid warnings
import warnings
warnings.filterwarnings('ignore')

# Set default plot style
sns.set_style('darkgrid')

# %%
import os

# %%
os.listdir(r"/Users/mani/Desktop/")
# Out:
# ['Screenshot 2024-09-22 at 4.58.48\u202fPM.png',
#  'Screenshot 2024-09-10 at 9.29.26\u202fAM (2).png',
#  'Screenshot 2024-09-22 at 4.58.03\u202fPM.png',
#  'Screenshot 2024-02-12 at 11.31.48\u202fPM.png',
#  'prime.py',
#  'IT policy and strategy',
#  'screenshots',
#  'Orders : Concierge.pdf',
#  '.DS_Store',
#  'Screenshot 2024-09-22 at 4.58.29\u202fPM.png',
#  'return mail.pdf',
#  '.localized',
#  'wilmu subjects',
#  'MANI RESUME updated(python).docx',
#  'deepika resume.pdf',
#  'Screenshot 2023-05-30 at 4.54.55 PM.png',
#  'MANI RESUME updated.docx',
#  'health',
#  'Screenshot 2024-09-22 at 4.58.17\u202fPM.png',
#  'deepika resume.docx',
#  'Screenshot 2024-09-22 at 4.58.42\u202fPM.png',
#  'If I were to receive a scholarship.docx',
#  'Screenshot 2024-09-22 at 4.57.51\u202fPM.png',
#  'Best Buy Order Details.pdf',
#  'Mani(vangaurd) resume.pdf',
#  'Screenshot 2024-09-22 at 5.49.29\u202fPM (2).png',
#  'resume(datadog).pdf',
#  'US docs',
#  'Screenshot 2024-09-22 at 4.58.23\u202fPM.png',
#  'sem fee',
#  'Screenshot 2024-08-14 at 9.02.16\u202fAM.png',
#  'covid.csv',
#  'python pycharm',
#  'AZ-900 Certificate.pdf',
#  'MANI WORK RESUME.docx',
#  'Mani(vangaurd) resume.docx',
#  'deepika',
#  'MANI RESUME.docx',
#  '~$EPD_data.xlsx',
#  'MANI WORK RESUME.pdf',
#  'Screenshot 2024-09-22 at 4.58.10\u202fPM.png',
#  ' Resume-pt.docx',
#  'Day to Day Evaluation.docx',
#  'MANI WORK RESUME(testing).docx',
#  'Screenshot 2024-09-22 at 4.58.55\u202fPM.png',
#  'Screenshot 2024-09-22 at 4.58.36\u202fPM.png',
#  'Marketing resume',
#  'resume(datadog).docx',
#  'Screenshot 2024-09-22 at 4.57.46\u202fPM.png',
#  'Movies',
#  'opt',
#  'KANCHARAKUNTLA DEEPIKA - certificate.pdf',
#  'Screenshot 2024-09-22 at 5.49.25\u202fPM (2).png',
#  'array.py',
#  'Student (F1)  visa check list.doc',
#  'Covid vaccinations.xlsx',
#  'loginsignupjava',
#  'EPD_data.csv',
#  'ATT bill.pdf',
#  'sai_Chandra_QA_Resume.pdf',
#  'MANI RESUME1.pdf',
#  'MANI RESUME updated(python).pdf',
#  'xray',
#  'Screenshot 2024-09-22 at 5.49.29\u202fPM.png',
#  'Screenshot 2024-09-22 at 5.49.25\u202fPM.png']

# %%
# !pip uninstall xlrd -y
# !pip install xlrd==2.0.1
# Out:
# Found existing installation: xlrd 2.0.1
# Uninstalling xlrd-2.0.1:
#   Successfully uninstalled xlrd-2.0.1
# Collecting xlrd==2.0.1
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1

# %%
data = pd.read_excel(r"/Users/mani/Documents/Data analytics projects/INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls")

# %%
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# 1                  4  ...                            4
# 2                  4  ...                            3
# 3                  4  ...                            2
# 4                  4  ...                            4
#
#    TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                          10                      2                   2
# 1                          20                      2                   3
# 2                          20                      2                   3
# 3                          23                      2                   2
# 4                          10                      1                   3
#
#    ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                            10                             7
# 1                             7                             7
# 2                            18                            13
# 3                            21                             6
# 4                             2                             2
#
#   YearsSinceLastPromotion  YearsWithCurrManager  Attrition  PerformanceRating
# 0                       0                     8         No                  3
# 1                       1                     7         No                  3
# 2                       1                    12         No                  4
# 3                      12                     6         No                  3
# 4                       2                     2         No                  3
#
# [5 rows x 28 columns]

# %%
data.tail()
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 1195   E100992   27  Female             Medical      Divorced         Sales
# 1196   E100993   37    Male       Life Sciences        Single   Development
# 1197   E100994   50    Male             Medical       Married   Development
# 1198   E100995   34  Female             Medical        Single  Data Science
# 1199   E100998   24  Female       Life Sciences        Single         Sales
#
#             EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 1195   Sales Executive       Travel_Frequently                 3
# 1196  Senior Developer           Travel_Rarely                10
# 1197  Senior Developer           Travel_Rarely                28
# 1198    Data Scientist           Travel_Rarely                 9
# 1199   Sales Executive           Travel_Rarely                 3
#
#       EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 1195                  1  ...                            2
# 1196                  2  ...                            1
# 1197                  1  ...                            3
# 1198                  3  ...                            2
# 1199                  2  ...                            1
#
#       TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 1195                           6                      3                   3
# 1196                           4                      2                   3
# 1197                          20                      3                   3
# 1198                           9                      3                   4
# 1199                           4                      3                   3
#
#       ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 1195                             6                             5
# 1196                             1                             0
# 1197                            20                             8
# 1198                             8                             7
# 1199                             2                             2
#
#      YearsSinceLastPromotion  YearsWithCurrManager  Attrition  \
# 1195                       0                     4         No
# 1196                       0                     0         No
# 1197                       3                     8         No
# 1198                       7                     7         No
# 1199                       2                     0        Yes
#
#       PerformanceRating
# 1195                  4
# 1196                  3
# 1197                  3
# 1198                  3
# 1199                  2
#
# [5 rows x 28 columns]

# %%
data.shape
# Out:
# (1200, 28)

# %%
data.size
# Out:
# 33600

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
#  12  EmpJobInvolvement             1200 non-null   int64
#  13  EmpJobLevel                   1200 non-null   int64
#  14  EmpJobSatisfaction            1200 non-null   int64
#  15  NumCompaniesWorked            1200 non-null   int64
#  16  OverTime                      1200 non-null   object
#  17  EmpLastSalaryHikePercent      1200 non-null   int64
#  18  EmpRelationshipSatisfaction   1200 non-null   int64
#  19  TotalWorkExperienceInYears    1200 non-null   int64
#  20  TrainingTimesLastYear         1200 non-null   int64
#  21  EmpWorkLifeBalance            1200 non-null   int64
#  22  ExperienceYearsAtThisCompany  1200 non-null   int64
#  23  ExperienceYearsInCurrentRole  1200 non-null   int64
#  24  YearsSinceLastPromotion       1200 non-null   int64
#  25  YearsWithCurrManager          1200 non-null   int64
#  26  Attrition                     1200 non-null   object
#  27  PerformanceRating             1200 non-null   int64
# dtypes: int64(19), object(9)
# memory usage: 262.6+ KB

# %%
data.columns
# Out:
# Index(['EmpNumber', 'Age', 'Gender', 'EducationBackground', 'MaritalStatus',
#        'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency',
#        'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction',
#        'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel',
#        'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'PerformanceRating'],
#       dtype='object')

# %%
data.describe().T
# Out:
#                                count       mean        std   min   25%   50%  \
# Age                           1200.0  36.918333   9.087289  18.0  30.0  36.0
# DistanceFromHome              1200.0   9.165833   8.176636   1.0   2.0   7.0
# EmpEducationLevel             1200.0   2.892500   1.044120   1.0   2.0   3.0
# EmpEnvironmentSatisfaction    1200.0   2.715833   1.090599   1.0   2.0   3.0
# EmpHourlyRate                 1200.0  65.981667  20.211302  30.0  48.0  66.0
# EmpJobInvolvement             1200.0   2.731667   0.707164   1.0   2.0   3.0
# EmpJobLevel                   1200.0   2.067500   1.107836   1.0   1.0   2.0
# EmpJobSatisfaction            1200.0   2.732500   1.100888   1.0   2.0   3.0
# NumCompaniesWorked            1200.0   2.665000   2.469384   0.0   1.0   2.0
# EmpLastSalaryHikePercent      1200.0  15.222500   3.625918  11.0  12.0  14.0
# EmpRelationshipSatisfaction   1200.0   2.725000   1.075642   1.0   2.0   3.0
# TotalWorkExperienceInYears    1200.0  11.330000   7.797228   0.0   6.0  10.0
# TrainingTimesLastYear         1200.0   2.785833   1.263446   0.0   2.0   3.0
# EmpWorkLifeBalance            1200.0   2.744167   0.699374   1.0   2.0   3.0
# ExperienceYearsAtThisCompany  1200.0   7.077500   6.236899   0.0   3.0   5.0
# ExperienceYearsInCurrentRole  1200.0   4.291667   3.613744   0.0   2.0   3.0
# YearsSinceLastPromotion       1200.0   2.194167   3.221560   0.0   0.0   1.0
# YearsWithCurrManager          1200.0   4.105000   3.541576   0.0   2.0   3.0
# PerformanceRating             1200.0   2.948333   0.518866   2.0   3.0   3.0
#
#                                75%    max
# Age                           43.0   60.0
# DistanceFromHome              14.0   29.0
# EmpEducationLevel              4.0    5.0
# EmpEnvironmentSatisfaction     4.0    4.0
# EmpHourlyRate                 83.0  100.0
# EmpJobInvolvement              3.0    4.0
# EmpJobLevel                    3.0    5.0
# EmpJobSatisfaction             4.0    4.0
# NumCompaniesWorked             4.0    9.0
# EmpLastSalaryHikePercent      18.0   25.0
# EmpRelationshipSatisfaction    4.0    4.0
# TotalWorkExperienceInYears    15.0   40.0
# TrainingTimesLastYear          3.0    6.0
# EmpWorkLifeBalance             3.0    4.0
# ExperienceYearsAtThisCompany  10.0   40.0
# ExperienceYearsInCurrentRole   7.0   18.0
# YearsSinceLastPromotion        3.0   15.0
# YearsWithCurrManager           7.0   17.0
# PerformanceRating              3.0    4.0

# %%
data.describe(include='object').T
# Out:
#                         count unique              top  freq
# EmpNumber                1200   1200         E1001000     1
# Gender                   1200      2             Male   725
# EducationBackground      1200      6    Life Sciences   492
# MaritalStatus            1200      3          Married   548
# EmpDepartment            1200      6            Sales   373
# EmpJobRole               1200     19  Sales Executive   270
# BusinessTravelFrequency  1200      3    Travel_Rarely   846
# OverTime                 1200      2               No   847
# Attrition                1200      2               No  1022

# %%
#UNIVARIATE ANALYSIS

# %%
#1.Age

# %%
plt.figure(figsize=(9,5))
sns.histplot(x='Age',data=data)
plt.xlabel('Age',fontsize=18)
plt.ylabel('Frequency',fontsize=18)
plt.title('Age Distribution',fontsize=22)
plt.show()

# %%
#Observation: The age distribution of employees shows that the majority fall between the ages of 25 and 40.

# %%
#2. Employee Hourly Rate

# %%
plt.figure(figsize=(9,5))
sns.histplot(x='EmpHourlyRate',data=data)
plt.xlabel('EmpHourlyRate',fontsize=18)
plt.ylabel('Frequency',fontsize=18)
plt.title('Employee Hourly Rate Distribution',fontsize=18)
plt.show()

# %%
#Observation: The most common hourly rate among employees is 45, indicating a potential cluster around this wage point.

# %%
#3.Total work experience in years

# %%
plt.figure(figsize=(9,5))
sns.histplot(x='TotalWorkExperienceInYears',data=data)
plt.xlabel('TotalWorkExperienceInYears',fontsize=18)
plt.ylabel('Frequency',fontsize=18)
plt.title('Work Experience Distribution',fontsize=18)
plt.show()

# %%
#Observation: Most employees have 5 to 10 years of experience, with a significant number having around 10 years.

# %%
#4. Experience in years at this company

# %%
plt.figure(figsize=(9,5))
sns.histplot(x='ExperienceYearsAtThisCompany',data=data)
plt.xlabel('ExperienceYearsAtThisCompany',fontsize=18)
plt.ylabel('Frequency',fontsize=18)
plt.title('This Company Experience Distribution',fontsize=18)
plt.show()

# %%
#Most of the employees who joined this company have experience between 0 to 5 years

# %%
#single plot is taking a lot of time so I decided to use sub plot to analyse all the features

# %%
count = data[['Gender', 'EducationBackground', 'MaritalStatus','BusinessTravelFrequency','DistanceFromHome',
              'EmpEducationLevel', 'EmpEnvironmentSatisfaction','EmpJobInvolvement', 'EmpJobLevel',
              'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime']]

plt.figure(figsize=(20,25)) # defining canvas size
plotno = 1 # counter

for column in count: 
    if plotno<=13:    
        plt.subplot(4,3,plotno) 
        sns.countplot(x=count[column]) 
        plt.xlabel(column,fontsize=18)
        plt.ylabel('Frequency',fontsize=18)
        plt.title('Distribution ',fontsize=18)
    plotno+=1 # counter increment
plt.tight_layout()
plt.show()

# %%
#5.Gender:
Most of the male present in the comapany
6.Education Background:
most of the education background of employee is Life science and medical, as well as marketing eduaction background employee is more than 100.
other eduacation background employee is less than 100.
7.MaritalStatus:
Most of the employee is married as well as less than 400 employee is single.
less than 300 employee mariatal status is divorced.
8.Business Travel Frequency:
Maximum no of employee travel rarely for company buisness purpose,less than 220 employee travel frequently
remaining less than 120 employee not travell for buisness purpose.
9.Distance From Home:
The range of distance between home to comapny is 1 to 29.
Maximum no of employee home to company distance is less than 10.
10.Educational Level:
Total range of educational level is 1 to 5,Maximum no of employee education level is 3 & 4.
2 education level employee is less than 250 and remianing 1 & 5 education level employee is less than 150.

# %%
11.Employee Environment Satisfaction:
Most of the employee Statisfaction is 3 & 4
1 & 2 enviroment satisfaction employee less than 250
12.Employee Job Involvement:
Most of the employee job involvement is 3 as well as 2 job involment employee is less than 300.
Remaining 1 and 4 job involvment employee is less than 100.
13.Employee Job Level:
The range of employee job kevel is 1 to 5,most of the employee job level is 1 & 2.
Minimum no of job level is 5, as well as 3 & 4 job level employee is less than 180.
14.Employee Job Satisfaction:
Most of the employee job satisfaction is 3 & 4 score as well as 1 & 2 score jon satisfaction employee is less than 250.
15.Number Companies Worked:
Maximum no of employee work with only one company.
less no of employee work in more than 5 companies.
16.Overtime:
Most no of employee on doing over time and less than 350 employee doing overtime in company

# %%
count2 = data[['EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction','TrainingTimesLastYear','EmpWorkLifeBalance',
               'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion','YearsWithCurrManager', 'Attrition', 
               'PerformanceRating']]  #Making nex feature list to plot the graph

plt.figure(figsize=(20,22)) # defining canvas size
plotno = 1 # counter

for column in count2: # iteration of columns / acessing the columns from count 
    if plotno<=10:    # set the limit
        plt.subplot(3,3,plotno) # # plotting 9 graphs (3-rows,3-columns) ,plotnumber is for count
        sns.countplot(x=count2[column]) # Plotting count plots because the feature data type is discerte and categorical
        plt.xlabel(column,fontsize=18)
        plt.ylabel('Frequency',fontsize=18)
        plt.title('Distribution ',fontsize=18)
    plotno+=1 # counter increment
plt.tight_layout()
plt.show()

# %%
Observation:
17.Employee Last Salary Hike Percent:
Most no of employee salary hike percentage between 11 to 14%.total range of salary hike is 11 to 25.
less than 80 employee last salary hike in between 15 to 19.
18.Employee Relationship Satisfaction:
The range of employee relationship satisfaction is 1 to 4,Most of the relation satisfaction is 3 & 4 as well as less than 250 employee with 1 & 2 relationship satisfaction.
19.Training Times LastYear:
The range of training time in last year between 0 to 6, Most of the employee doing 2 & 3 rd time training and remaining all times is less than 100.
20.Employee Work Life Balance:
Most most the work life balance is 3 than less than 300 employee work life balance is 2.
Minimum work life balance is 1 as well as less than 100 employee work life balance is 4.
21.Experiance In Current Role:
Maximum current role experiance of employee is 18.
Most of the employee have 2 years of expriance in current role then 7 year of experiance employee is less than 180
less than 200 employee have not current role experiance.

# %%
22.Years Since Last Promotion:
The range of year since last promotion is 0 to 15.
Most of the employee has not promoted in last year less than 300 employee has promoted atleast 1 year.
23.Years With Current Manager:
Most employee have 2 years with current manager and minimum 16 years with current manager.
The range in between 0 to 17 and less than 180 employee has 7 years with current manager.
24.Attrition:
Maximum no of employee has not leave the company and less than 200 employee has going to leave the company.
25. Target Feature == Performance Rating:
The range of performance rating is 2 to 4, most of the employee have 3 performance ranting and less performance rating is 4.
less than 200 employee has 2 performance rating.

# %%
#26. Employee Department

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='EmpDepartment',data=data)
plt.xlabel('EmpDepartment',fontsize=18)
plt.ylabel('Frequency',fontsize=18)
plt.title('EmpDepartment Distribution ',fontsize=18)
plt.show()

# %%
#Observation:

Most of the employee from sales department as well as Development and research & Development departmnet employee is less than 320
Human resources & finance department employee is almost equal.
Data science employee has minimum in company.

# %%
#27.Employee Job Role

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='EmpJobRole',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('EmpJobRole',fontsize=18)
plt.ylabel('Frequency',fontsize=18)
plt.title('EmpJobRole Distribution ',fontsize=18)
plt.show()

# %%
#BIVARIATE ANALYSIS

# %%
#I need to check relation between different features
#Analysis on continuous features in the data

# %%
# First plot that I want to use is Histgram, line plot in order to analyse continuous data features

# %%
#1 defining relation between age and total experience

# %%
plt.figure(figsize=(20,10))
plt.grid(True)
sns.lineplot(x='Age', y='TotalWorkExperienceInYears',data=data)
plt.xlabel('Age',fontsize=18)
plt.ylabel('TotalWorkExperienceInYears',fontsize=18)
plt.title('Relation',fontsize=18)
plt.show()

# %%
#2. What could be the relation between experience at this company and total experience

# %%
plt.figure(figsize=(20,10))
plt.grid(True)
sns.lineplot(x='ExperienceYearsAtThisCompany', y='TotalWorkExperienceInYears',data=data)
plt.xlabel('ExperienceYearsAtThisCompany',fontsize=18)
plt.ylabel('TotalWorkExperienceInYears',fontsize=18)
plt.title('Relation',fontsize=18)
plt.show()

# %%
#3.

# %%
plt.figure(figsize=(20,10))
plt.grid(True)
sns.lineplot(x='EmpLastSalaryHikePercent',y='NumCompaniesWorked',data=data)
plt.xlabel('EmpLastSalaryHikePercent',fontsize=18)
plt.ylabel('NumCompaniesWorked',fontsize=18)
plt.title('relation',fontsize=20)
plt.show()

# %%
#4.

# %%
plt.figure(figsize=(20,10))
plt.grid(True)
sns.lineplot(x='YearsSinceLastPromotion',y='ExperienceYearsInCurrentRole',data=data)
plt.xlabel('YearsSinceLastPromotion',fontsize=18)
plt.ylabel('ExperienceYearsInCurrentRole',fontsize=18)
plt.title('relation',fontsize=20)
plt.show()

# %%
#5.

# %%
plt.figure(figsize=(20,10))
plt.grid(True)
sns.lineplot(x='EmpHourlyRate',y='YearsWithCurrManager',data=data)
plt.xlabel('EmpHourlyRate',fontsize=18)
plt.ylabel('YearsWithCurrManager',fontsize=18)
plt.title('relation',fontsize=20)
plt.show()

# %%
#6.

# %%
plt.figure(figsize=(20,10))
plt.grid(True)
sns.lineplot(x='DistanceFromHome',y='EmpLastSalaryHikePercent',data=data)
plt.xlabel('DistanceFromHome',fontsize=15)
plt.ylabel('EmpLastSalaryHikePercent',fontsize=18)
plt.title('relation',fontsize=20)
plt.show()

# %%
#now I can go ahead with categorical and discrete features analysis

# %%
#7-12Creating a list of all categorical features makes an easy way to analyse the data

# %%
categorical = []  
for column in data.columns:
    if data[column].dtype == object:
        categorical.append(column)
        print(f"{column} : {data[column].unique()}")
        print("====================================")
# Out:
# EmpNumber : ['E1001000' 'E1001006' 'E1001007' ... 'E100994' 'E100995' 'E100998']
# ====================================
# Gender : ['Male' 'Female']
# ====================================
# EducationBackground : ['Marketing' 'Life Sciences' 'Human Resources' 'Medical' 'Other'
#  'Technical Degree']
# ====================================
# MaritalStatus : ['Single' 'Married' 'Divorced']
# ====================================
# EmpDepartment : ['Sales' 'Human Resources' 'Development' 'Data Science'
#  'Research & Development' 'Finance']
# ====================================
# EmpJobRole : ['Sales Executive' 'Manager' 'Developer' 'Sales Representative'
#  'Human Resources' 'Senior Developer' 'Data Scientist'
#  'Senior Manager R&D' 'Laboratory Technician' 'Manufacturing Director'
#  'Research Scientist' 'Healthcare Representative' 'Research Director'
#  'Manager R&D' 'Finance Manager' 'Technical Architect' 'Business Analyst'
#  'Technical Lead' 'Delivery Manager']
# ====================================
# BusinessTravelFrequency : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# ====================================
# OverTime : ['No' 'Yes']
# ====================================
# Attrition : ['No' 'Yes']
# ====================================

# %%
categorical
# Out:
# ['EmpNumber',
#  'Gender',
#  'EducationBackground',
#  'MaritalStatus',
#  'EmpDepartment',
#  'EmpJobRole',
#  'BusinessTravelFrequency',
#  'OverTime',
#  'Attrition']

# %%
categorical_col = data[['Gender','EducationBackground','MaritalStatus','BusinessTravelFrequency','OverTime','Attrition']]
plt.figure(figsize=(20,22)) 
plotno = 1

for column in categorical_col: 
    if plotno<=7:    
        plt.subplot(3,2,plotno)
        sns.countplot(x=categorical_col[column],hue=data.PerformanceRating) 
        plt.xlabel(column,fontsize=18)  
        plt.ylabel('PerformanceRating',fontsize=16)
        plt.title('Relation',fontsize=20)
    plotno+=1 
plt.tight_layout()
plt.show()

# %%
#13.

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='EmpDepartment',hue=data.PerformanceRating,data=data)
plt.xlabel('EmpDepartment',fontsize=18)
plt.ylabel('PerformanceRating',fontsize=16)
plt.title('Relation',fontsize=20)
plt.show()

# %%
#14.

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='EmpJobRole',hue=data.PerformanceRating,data=data)
plt.xticks(rotation='vertical')
plt.xlabel('EmpJobRole',fontsize=18)
plt.ylabel('PerformanceRating',fontsize=16)
plt.title('Relation',fontsize=20)
plt.show()

# %%
#Next Analysis can be done for Numerical features

# %%
#in order to do analysis for numerical features I need to create a list of all numerical features

# %%
#16-20

# %%
numerical = data[['EmpEducationLevel','EmpEnvironmentSatisfaction','EmpJobInvolvement','EmpJobLevel','EmpJobSatisfaction',
                 'EmpWorkLifeBalance']]

plt.figure(figsize=(20,22))
plotno = 1 

for column in numerical: 
    if plotno<=7:    
        plt.subplot(3,2,plotno) 
        sns.countplot(x=numerical[column],hue=data.PerformanceRating) 
        plt.xlabel(column,fontsize=18)  
        plt.ylabel('PerformanceRating',fontsize=16)
        plt.title('Relation',fontsize=20)
    plotno+=1 
plt.tight_layout()
plt.show()

# %%
#Observations:

# %%
#MultiVariate Analysis: We need to check the relationship between multiple features and target features

# %%
#Firstly I want to find correlations between all the columns in the data. I am going to define a correlation matrix inorder to understand relations between each feature

# %%
#1.

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='Age',y='TotalWorkExperienceInYears',hue=data.PerformanceRating,data=data)
plt.xlabel('Age',fontsize=18)
plt.ylabel('TotalWorkExperienceInYears',fontsize=16)
plt.title('Analysis with Target Feature', fontsize=20)
plt.show()

# %%
#2.

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Gender',y='NumCompaniesWorked',hue=data.PerformanceRating,data=data)
plt.xlabel('Gender',fontsize=18)
plt.ylabel('NumCompaniesWorked',fontsize=16)
plt.title('Analysis with Target Feature', fontsize=20)
plt.title('Analysis with Target Feature', fontsize=20)
plt.show()

# %%
#3.

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='EducationBackground',y='ExperienceYearsInCurrentRole',hue=data.PerformanceRating,data=data)
plt.xlabel('EducationBackground',fontsize=18)
plt.ylabel('ExperienceYearsInCurrentRole',fontsize=16)
plt.title('Analysis with Target Feature', fontsize=20)
plt.show()

# %%
#4

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='OverTime',y='DistanceFromHome',hue=data.PerformanceRating,data=data)
plt.xlabel('OverTime',fontsize=18)
plt.ylabel('DistanceFromHome',fontsize=16)
plt.title('Analysis with Target Feature', fontsize=20)
plt.show()

# %%
#5.

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='EmpDepartment',y='TrainingTimesLastYear',hue=data.PerformanceRating,data=data)
plt.xlabel('EmpDepartment',fontsize=18)
plt.ylabel('TrainingTimesLastYear',fontsize=16)
plt.title('Analysis with Target Feature', fontsize=20)
plt.show()

# %%
#6.

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='MaritalStatus',y='EmpLastSalaryHikePercent',hue=data.PerformanceRating,data=data)
plt.xlabel('MaritalStatus',fontsize=18)
plt.ylabel('EmpLastSalaryHikePercent',fontsize=16)
plt.title('Analysis with Target Feature', fontsize=20)
plt.show()

# %%
#7.

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Attrition',y='NumCompaniesWorked',hue=data.PerformanceRating,data=data)
plt.xlabel('Attrition',fontsize=18)
plt.ylabel('NumCompaniesWorked',fontsize=16)
plt.title('Analysis with Target Feature', fontsize=20)
plt.show()

# %%
#8.

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Attrition',y='YearsWithCurrManager',hue=data.PerformanceRating,data=data)
plt.xlabel('Attrition',fontsize=18)
plt.ylabel('YearsWithCurrManager',fontsize=16)
plt.title('Analysis with Target Feature', fontsize=20)
plt.show()

# %%
#9.

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='BusinessTravelFrequency',y='EmpEnvironmentSatisfaction',hue=data.PerformanceRating,data=data)
plt.xlabel('BusinessTravelFrequency',fontsize=18)
plt.ylabel('EmpEnvironmentSatisfaction',fontsize=16)
plt.title('Analysis with Target Feature', fontsize=20)
plt.show()

# %%
#Department Wise Performance Rating

# %%
# Correlation heatmap for numerical columns
def correlation_heatmap(df):
    numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
    plt.figure(figsize=(12, 8))
    corr_matrix = df[numerical_cols].corr()
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
    plt.title('Correlation Heatmap', fontsize=22)
    plt.show()

# Call the function
correlation_heatmap(data)

# %%
from sklearn.preprocessing import LabelEncoder

enc = LabelEncoder()
for i in (2,3,4,5,6,7,16,26):
    data.iloc[:,i] = enc.fit_transform(data.iloc[:,i])
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus EmpDepartment  \
# 0  E1001000   32      1                   2             2             5
# 1  E1001006   47      1                   2             2             5
# 2  E1001007   40      1                   1             1             5
# 3  E1001009   41      1                   0             0             3
# 4  E1001010   60      1                   2             2             5
#
#   EmpJobRole BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0         13                       2                10                  3
# 1         13                       2                14                  4
# 2         13                       1                 5                  4
# 3          8                       2                10                  4
# 4         13                       2                16                  4
#
#    ...  EmpRelationshipSatisfaction  TotalWorkExperienceInYears  \
# 0  ...                            4                          10
# 1  ...                            4                          20
# 2  ...                            3                          20
# 3  ...                            2                          23
# 4  ...                            4                          10
#
#    TrainingTimesLastYear  EmpWorkLifeBalance  ExperienceYearsAtThisCompany  \
# 0                      2                   2                            10
# 1                      2                   3                             7
# 2                      2                   3                            18
# 3                      2                   2                            21
# 4                      1                   3                             2
#
#    ExperienceYearsInCurrentRole YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                             7                       0                     8
# 1                             7                       1                     7
# 2                            13                       1                    12
# 3                             6                      12                     6
# 4                             2                       2                     2
#
#    Attrition  PerformanceRating
# 0          0                  3
# 1          0                  3
# 2          0                  4
# 3          0                  3
# 4          0                  3
#
# [5 rows x 28 columns]

# %%
print(data.columns)
# Out:
# Index(['EmpNumber', 'Age', 'Gender', 'EducationBackground', 'MaritalStatus',
#        'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency',
#        'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction',
#        'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel',
#        'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'PerformanceRating'],
#       dtype='object')

# %%
data['EmpNumber'] = pd.to_numeric(data['EmpNumber'], errors='coerce')

# %%
# Strip spaces and make column names lowercase
data.columns = data.columns.str.strip().str.lower()

# %%
data.corr()
# Out:
#                               empnumber       age    gender  \
# empnumber                           NaN       NaN       NaN
# age                                 NaN  1.000000 -0.040107
# gender                              NaN -0.040107  1.000000
# educationbackground                 NaN -0.055905  0.009922
# maritalstatus                       NaN -0.098368 -0.042169
# empdepartment                       NaN -0.000104 -0.010925
# empjobrole                          NaN -0.037665  0.011332
# businesstravelfrequency             NaN  0.040579 -0.043608
# distancefromhome                    NaN  0.020937 -0.001507
# empeducationlevel                   NaN  0.207313 -0.022960
# empenvironmentsatisfaction          NaN  0.013814  0.000033
# emphourlyrate                       NaN  0.062867  0.002218
# empjobinvolvement                   NaN  0.027216  0.010949
# empjoblevel                         NaN  0.509139 -0.050685
# empjobsatisfaction                  NaN -0.002436  0.024680
# numcompaniesworked                  NaN  0.284408 -0.036675
# overtime                            NaN  0.051910 -0.038410
# emplastsalaryhikepercent            NaN -0.006105 -0.005319
# emprelationshipsatisfaction         NaN  0.049749  0.030707
# totalworkexperienceinyears          NaN  0.680886 -0.061055
# trainingtimeslastyear               NaN -0.016053 -0.057654
# empworklifebalance                  NaN -0.019563  0.015793
# experienceyearsatthiscompany        NaN  0.318852 -0.030392
# experienceyearsincurrentrole        NaN  0.217163 -0.031823
# yearssincelastpromotion             NaN  0.228199 -0.021575
# yearswithcurrmanager                NaN  0.205098 -0.036643
# attrition                           NaN -0.189317  0.035758
# performancerating                   NaN -0.040164 -0.001780
#
#                               educationbackground  maritalstatus  \
# empnumber                                     NaN            NaN
# age                                     -0.055905      -0.098368
# gender                                   0.009922      -0.042169
# educationbackground                      1.000000      -0.001097
# maritalstatus                           -0.001097       1.000000
# empdepartment                           -0.026874       0.067272
# empjobrole                              -0.012325       0.038023
# businesstravelfrequency                  0.012382       0.028520
# distancefromhome                        -0.013919      -0.019148
# empeducationlevel                       -0.047978       0.026737
# empenvironmentsatisfaction               0.045028      -0.032467
# emphourlyrate                           -0.030234      -0.013540
# empjobinvolvement                       -0.025505      -0.043355
# empjoblevel                             -0.056338      -0.087359
# empjobsatisfaction                      -0.030977       0.044593
# numcompaniesworked                      -0.032879      -0.030095
# overtime                                 0.007046      -0.022833
# emplastsalaryhikepercent                -0.009788       0.010128
# emprelationshipsatisfaction              0.005652       0.026410
# totalworkexperienceinyears              -0.027929      -0.093537
# trainingtimeslastyear                    0.051596       0.026045
# empworklifebalance                       0.022890       0.014154
# experienceyearsatthiscompany            -0.009887      -0.075728
# experienceyearsincurrentrole            -0.003215      -0.076663
# yearssincelastpromotion                  0.014277      -0.052951
# yearswithcurrmanager                     0.002767      -0.061908
# attrition                                0.027161       0.162969
# performancerating                        0.005607       0.024172
#
#                               empdepartment  empjobrole  \
# empnumber                               NaN         NaN
# age                               -0.000104   -0.037665
# gender                            -0.010925    0.011332
# educationbackground               -0.026874   -0.012325
# maritalstatus                      0.067272    0.038023
# empdepartment                      1.000000    0.568973
# empjobrole                         0.568973    1.000000
# businesstravelfrequency           -0.045233   -0.086251
# distancefromhome                   0.007707    0.022939
# empeducationlevel                  0.019175   -0.016792
# empenvironmentsatisfaction        -0.019237    0.044612
# emphourlyrate                      0.003957   -0.016179
# empjobinvolvement                 -0.076988   -0.008034
# empjoblevel                        0.100526    0.004406
# empjobsatisfaction                 0.007150    0.032916
# numcompaniesworked                -0.033950   -0.009111
# overtime                          -0.026841    0.015075
# emplastsalaryhikepercent          -0.012661    0.005735
# emprelationshipsatisfaction       -0.050286   -0.043067
# totalworkexperienceinyears         0.016065   -0.049529
# trainingtimeslastyear              0.016438    0.004452
# empworklifebalance                 0.068875   -0.007519
# experienceyearsatthiscompany       0.047677   -0.009047
# experienceyearsincurrentrole       0.069602    0.019383
# yearssincelastpromotion            0.052315    0.012190
# yearswithcurrmanager               0.033850   -0.004504
# attrition                          0.048006    0.037508
# performancerating                 -0.162615   -0.096209
#
#                               businesstravelfrequency  distancefromhome  \
# empnumber                                         NaN               NaN
# age                                          0.040579          0.020937
# gender                                      -0.043608         -0.001507
# educationbackground                          0.012382         -0.013919
# maritalstatus                                0.028520         -0.019148
# empdepartment                               -0.045233          0.007707
# empjobrole                                  -0.086251          0.022939
# businesstravelfrequency                      1.000000         -0.020935
# distancefromhome                            -0.020935          1.000000
# empeducationlevel                            0.002064          0.045856
# empenvironmentsatisfaction                   0.012267         -0.017719
# emphourlyrate                                0.025400          0.013730
# empjobinvolvement                            0.016652          0.003231
# empjoblevel                                  0.036360          0.017270
# empjobsatisfaction                          -0.031236         -0.003036
# numcompaniesworked                           0.021476         -0.021411
# overtime                                     0.032229          0.024940
# emplastsalaryhikepercent                    -0.041946          0.044974
# emprelationshipsatisfaction                 -0.032705         -0.009509
# totalworkexperienceinyears                   0.042736          0.027306
# trainingtimeslastyear                        0.006720         -0.032082
# empworklifebalance                          -0.040969         -0.044788
# experienceyearsatthiscompany                -0.015029          0.021908
# experienceyearsincurrentrole                -0.006541          0.019898
# yearssincelastpromotion                     -0.020824          0.013246
# yearswithcurrmanager                        -0.028073          0.017860
# attrition                                    0.007217          0.063248
# performancerating                           -0.031025         -0.046142
#
#                               empeducationlevel  ...  \
# empnumber                                   NaN  ...
# age                                    0.207313  ...
# gender                                -0.022960  ...
# educationbackground                   -0.047978  ...
# maritalstatus                          0.026737  ...
# empdepartment                          0.019175  ...
# empjobrole                            -0.016792  ...
# businesstravelfrequency                0.002064  ...
# distancefromhome                       0.045856  ...
# empeducationlevel                      1.000000  ...
# empenvironmentsatisfaction            -0.037103  ...
# emphourlyrate                          0.014095  ...
# empjobinvolvement                      0.027544  ...
# empjoblevel                            0.100734  ...
# empjobsatisfaction                     0.000357  ...
# numcompaniesworked                     0.128674  ...
# overtime                              -0.021119  ...
# emplastsalaryhikepercent               0.002358  ...
# emprelationshipsatisfaction           -0.016690  ...
# totalworkexperienceinyears             0.151062  ...
# trainingtimeslastyear                 -0.013674  ...
# empworklifebalance                     0.010276  ...
# experienceyearsatthiscompany           0.076332  ...
# experienceyearsincurrentrole           0.066672  ...
# yearssincelastpromotion                0.054313  ...
# yearswithcurrmanager                   0.088988  ...
# attrition                             -0.049118  ...
# performancerating                      0.020529  ...
#
#                               emprelationshipsatisfaction  \
# empnumber                                             NaN
# age                                              0.049749
# gender                                           0.030707
# educationbackground                              0.005652
# maritalstatus                                    0.026410
# empdepartment                                   -0.050286
# empjobrole                                      -0.043067
# businesstravelfrequency                         -0.032705
# distancefromhome                                -0.009509
# empeducationlevel                               -0.016690
# empenvironmentsatisfaction                      -0.010504
# emphourlyrate                                    0.008783
# empjobinvolvement                                0.018037
# empjoblevel                                      0.002992
# empjobsatisfaction                              -0.022028
# numcompaniesworked                               0.057917
# overtime                                         0.034146
# emplastsalaryhikepercent                        -0.042892
# emprelationshipsatisfaction                      1.000000
# totalworkexperienceinyears                       0.018089
# trainingtimeslastyear                            0.025975
# empworklifebalance                              -0.004906
# experienceyearsatthiscompany                     0.015612
# experienceyearsincurrentrole                    -0.032131
# yearssincelastpromotion                          0.026253
# yearswithcurrmanager                            -0.006426
# attrition                                       -0.037179
# performancerating                               -0.019502
#
#                               totalworkexperienceinyears  \
# empnumber                                            NaN
# age                                             0.680886
# gender                                         -0.061055
# educationbackground                            -0.027929
# maritalstatus                                  -0.093537
# empdepartment                                   0.016065
# empjobrole                                     -0.049529
# businesstravelfrequency                         0.042736
# distancefromhome                                0.027306
# empeducationlevel                               0.151062
# empenvironmentsatisfaction                     -0.012894
# emphourlyrate                                   0.026034
# empjobinvolvement                              -0.028851
# empjoblevel                                     0.784229
# empjobsatisfaction                             -0.026824
# numcompaniesworked                              0.221505
# overtime                                        0.044233
# emplastsalaryhikepercent                       -0.005933
# emprelationshipsatisfaction                     0.018089
# totalworkexperienceinyears                      1.000000
# trainingtimeslastyear                          -0.022113
# empworklifebalance                              0.015495
# experienceyearsatthiscompany                    0.633555
# experienceyearsincurrentrole                    0.460700
# yearssincelastpromotion                         0.412781
# yearswithcurrmanager                            0.460783
# attrition                                      -0.185226
# performancerating                              -0.068141
#
#                               trainingtimeslastyear  empworklifebalance  \
# empnumber                                       NaN                 NaN
# age                                       -0.016053           -0.019563
# gender                                    -0.057654            0.015793
# educationbackground                        0.051596            0.022890
# maritalstatus                              0.026045            0.014154
# empdepartment                              0.016438            0.068875
# empjobrole                                 0.004452           -0.007519
# businesstravelfrequency                    0.006720           -0.040969
# distancefromhome                          -0.032082           -0.044788
# empeducationlevel                         -0.013674            0.010276
# empenvironmentsatisfaction                 0.001192           -0.000262
# emphourlyrate                             -0.024160            0.016189
# empjobinvolvement                         -0.025168           -0.014129
# empjoblevel                               -0.000389            0.049218
# empjobsatisfaction                        -0.028031           -0.018548
# numcompaniesworked                        -0.050817            0.002489
# overtime                                  -0.061398           -0.027968
# emplastsalaryhikepercent                  -0.013439           -0.017001
# emprelationshipsatisfaction                0.025975           -0.004906
# totalworkexperienceinyears                -0.022113            0.015495
# trainingtimeslastyear                      1.000000            0.037048
# empworklifebalance                         0.037048            1.000000
# experienceyearsatthiscompany               0.008564            0.023479
# experienceyearsincurrentrole               0.010222            0.045719
# yearssincelastpromotion                    0.018831            0.015773
# yearswithcurrmanager                      -0.013237            0.010518
# attrition                                 -0.035047           -0.068624
# performancerating                         -0.005443            0.124429
#
#                               experienceyearsatthiscompany  \
# empnumber                                              NaN
# age                                               0.318852
# gender                                           -0.030392
# educationbackground                              -0.009887
# maritalstatus                                    -0.075728
# empdepartment                                     0.047677
# empjobrole                                       -0.009047
# businesstravelfrequency                          -0.015029
# distancefromhome                                  0.021908
# empeducationlevel                                 0.076332
# empenvironmentsatisfaction                       -0.000561
# emphourlyrate                                    -0.000399
# empjobinvolvement                                -0.039720
# empjoblevel                                       0.540377
# empjobsatisfaction                                0.001807
# numcompaniesworked                               -0.129797
# overtime                                          0.004295
# emplastsalaryhikepercent                         -0.019830
# emprelationshipsatisfaction                       0.015612
# totalworkexperienceinyears                        0.633555
# trainingtimeslastyear                             0.008564
# empworklifebalance                                0.023479
# experienceyearsatthiscompany                      1.000000
# experienceyearsincurrentrole                      0.764102
# yearssincelastpromotion                           0.620230
# yearswithcurrmanager                              0.759258
# attrition                                        -0.142456
# performancerating                                -0.111645
#
#                               experienceyearsincurrentrole  \
# empnumber                                              NaN
# age                                               0.217163
# gender                                           -0.031823
# educationbackground                              -0.003215
# maritalstatus                                    -0.076663
# empdepartment                                     0.069602
# empjobrole                                        0.019383
# businesstravelfrequency                          -0.006541
# distancefromhome                                  0.019898
# empeducationlevel                                 0.066672
# empenvironmentsatisfaction                        0.025491
# emphourlyrate                                    -0.011871
# empjobinvolvement                                 0.002910
# empjoblevel                                       0.399235
# empjobsatisfaction                                0.002018
# numcompaniesworked                               -0.097271
# overtime                                         -0.015674
# emplastsalaryhikepercent                         -0.004957
# emprelationshipsatisfaction                      -0.032131
# totalworkexperienceinyears                        0.460700
# trainingtimeslastyear                             0.010222
# empworklifebalance                                0.045719
# experienceyearsatthiscompany                      0.764102
# experienceyearsincurrentrole                      1.000000
# yearssincelastpromotion                           0.540600
# yearswithcurrmanager                              0.728973
# attrition                                        -0.173895
# performancerating                                -0.147638
#
#                               yearssincelastpromotion  yearswithcurrmanager  \
# empnumber                                         NaN                   NaN
# age                                          0.228199              0.205098
# gender                                      -0.021575             -0.036643
# educationbackground                          0.014277              0.002767
# maritalstatus                               -0.052951             -0.061908
# empdepartment                                0.052315              0.033850
# empjobrole                                   0.012190             -0.004504
# businesstravelfrequency                     -0.020824             -0.028073
# distancefromhome                             0.013246              0.017860
# empeducationlevel                            0.054313              0.088988
# empenvironmentsatisfaction                   0.010732             -0.011702
# emphourlyrate                               -0.010000             -0.004576
# empjobinvolvement                           -0.019944              0.012924
# empjoblevel                                  0.360880              0.374872
# empjobsatisfaction                          -0.006508             -0.022096
# numcompaniesworked                          -0.031656             -0.109937
# overtime                                     0.000261             -0.028447
# emplastsalaryhikepercent                    -0.015911             -0.007666
# emprelationshipsatisfaction                  0.026253             -0.006426
# totalworkexperienceinyears                   0.412781              0.460783
# trainingtimeslastyear                        0.018831             -0.013237
# empworklifebalance                           0.015773              0.010518
# experienceyearsatthiscompany                 0.620230              0.759258
# experienceyearsincurrentrole                 0.540600              0.728973
# yearssincelastpromotion                      1.000000              0.491199
# yearswithcurrmanager                         0.491199              1.000000
# attrition                                   -0.057199             -0.158745
# performancerating                           -0.167629             -0.122313
#
#                               attrition  performancerating
# empnumber                           NaN                NaN
# age                           -0.189317          -0.040164
# gender                         0.035758          -0.001780
# educationbackground            0.027161           0.005607
# maritalstatus                  0.162969           0.024172
# empdepartment                  0.048006          -0.162615
# empjobrole                     0.037508          -0.096209
# businesstravelfrequency        0.007217          -0.031025
# distancefromhome               0.063248          -0.046142
# empeducationlevel             -0.049118           0.020529
# empenvironmentsatisfaction    -0.123490           0.395561
# emphourlyrate                 -0.026313          -0.043116
# empjobinvolvement             -0.153360          -0.010539
# empjoblevel                   -0.175763          -0.076632
# empjobsatisfaction            -0.081783           0.000606
# numcompaniesworked             0.037643           0.020980
# overtime                       0.224535           0.050206
# emplastsalaryhikepercent      -0.009448           0.333722
# emprelationshipsatisfaction   -0.037179          -0.019502
# totalworkexperienceinyears    -0.185226          -0.068141
# trainingtimeslastyear         -0.035047          -0.005443
# empworklifebalance            -0.068624           0.124429
# experienceyearsatthiscompany  -0.142456          -0.111645
# experienceyearsincurrentrole  -0.173895          -0.147638
# yearssincelastpromotion       -0.057199          -0.167629
# yearswithcurrmanager          -0.158745          -0.122313
# attrition                      1.000000          -0.039796
# performancerating             -0.039796           1.000000
#
# [28 rows x 28 columns]

# %%
# Check the column names in the dataset
print(data.columns)
# Out:
# Index(['empnumber', 'age', 'gender', 'educationbackground', 'maritalstatus',
#        'empdepartment', 'empjobrole', 'businesstravelfrequency',
#        'distancefromhome', 'empeducationlevel', 'empenvironmentsatisfaction',
#        'emphourlyrate', 'empjobinvolvement', 'empjoblevel',
#        'empjobsatisfaction', 'numcompaniesworked', 'overtime',
#        'emplastsalaryhikepercent', 'emprelationshipsatisfaction',
#        'totalworkexperienceinyears', 'trainingtimeslastyear',
#        'empworklifebalance', 'experienceyearsatthiscompany',
#        'experienceyearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'attrition', 'performancerating'],
#       dtype='object')

# %%
# Step 1: Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
import joblib



# Encode categorical variables
label_encoder = LabelEncoder()
for column in data.select_dtypes(include='object').columns:
    data[column] = label_encoder.fit_transform(data[column])

# Step 3: Define features (X) and target (y)
X = data.drop('performancerating', axis=1)  # Features: all columns except 'PerformanceRating'
y = data['performancerating']  # Target: Performance Rating

# Step 4: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 5: Train the Random Forest Classifier
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Step 6: Evaluate the model on the test data
y_pred = rf_model.predict(X_test)  # Predictions for the test set

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy*100:.2f}%")

# Classification Report for detailed performance metrics
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Model Accuracy: 92.50%
# Classification Report:
#               precision    recall  f1-score   support
#
#            2       0.88      0.88      0.88        49
#            3       0.93      0.97      0.95       268
#            4       0.94      0.70      0.80        43
#
#     accuracy                           0.93       360
#    macro avg       0.92      0.85      0.88       360
# weighted avg       0.93      0.93      0.92       360

# %%
# Step 7: Predict performance for new employees
# Example input for a new employee (replace with actual candidate data)
new_employee = pd.DataFrame({
    'empnumber': [0],  # EmpNumber is just an identifier, exclude it in real scenarios
    'age': [28],
    'gender': [1],  # 1 for Male, 0 for Female (use encoded values)
    'educationbackground': [3],
    'maritalstatus': [1],  # Encoded marital status
    'empdepartment': [2],  # Encoded department value
    'empjobrole': [4],  # Encoded job role
    'businesstravelfrequency': [1],  # Encoded travel frequency
    'distancefromhome': [8],  # Example distance
    'empeducationlevel': [3],
    'empenvironmentsatisfaction': [4],
    'emphourlyrate': [25],  # Hourly rate
    'empjobinvolvement': [3],
    'empjoblevel': [2],  # Job level
    'empjobsatisfaction': [3],
    'numcompaniesworked': [2],  # Number of companies worked
    'overtime': [0],  # 1: Yes, 0: No for overtime
    'emplastsalaryhikepercent': [10],  # Last salary hike percentage
    'emprelationshipsatisfaction': [3],  # Relationship satisfaction
    'totalworkexperienceinyears': [7],
    'trainingtimeslastyear': [2],
    'empworklifebalance': [3],
    'experienceyearsatthiscompany': [4],
    'experienceyearsincurrentrole': [2],
    'yearssincelastpromotion': [1],
    'yearswithcurrmanager': [2],
    'attrition': [0]  # Encoded attrition status
})

# Predict performance rating for the new employee
new_employee_pred = rf_model.predict(new_employee)
print(f"Predicted Performance Rating for New Employee: {new_employee_pred[0]}")
# Out:
# Predicted Performance Rating for New Employee: 3
